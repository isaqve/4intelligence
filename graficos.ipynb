# %%
#EQUIPAMENTOS E MATERIAIS PARA ESCRITÓRIO, INFORMÁTICA E COMUNICAÇÃO NO ESTADO DE SP
import pandas as pd


data = pd.read_csv('sp.csv',sep=';',header = None)
data = pd.DataFrame(data)

import matplotlib.pyplot as plt
x = data[0]
y = data[1]
plt.plot(x, y,'r--')
plt.xlabel("Tempo")
plt.ylabel("Volume")
plt.title('Volume de vendas de Equipamentos e materiais para escritório, informática e comunicação no estado de São Paulo', fontsize = 24)
plt.yticks(ticks=[40.0,50.0,60.0,70.0,80.0,90.0,100.0,110.0,120.0,130.0,140.0], labels = [40.0,50.0,60.0,70.0,80.0,90.0,100.0,110.0,120.0,130.0,140.0])
plt.xticks(ticks=["abr/19","maio/19","jun/19","jul/19","ago/19","set/19","out/19","nov/19","dez/19","jan/20","fev/20","mar/20","abr/20"
], labels = ["abr/19","maio/19","jun/19","jul/19","ago/19","set/19","out/19","nov/19","dez/19","jan/20","fev/20","mar/20","abr/20"])
plt.gcf().set_size_inches(20, 18)
plt.show()

#OUTROS ARTIGOS DE USO PESSOAL E DOMÉSTICO NO ESTADO DE SP 
import pandas as pd

data = pd.read_csv('sp-domestico.csv',sep=';',header = None)
data = pd.DataFrame(data)

import matplotlib.pyplot as plt
x = data[0]
y = data[1]
plt.plot(x, y,'r--')
plt.xlabel("Tempo")
plt.ylabel("Volume")
plt.title('Volume de vendas de Outros artigos de uso pessoal e doméstico no estado de São Paulo', fontsize = 24)
plt.yticks(ticks=[40.0,50.0,60.0,70.0,80.0,90.0,100.0,110.0,120.0,130.0,140.0], labels = [40.0,50.0,60.0,70.0,80.0,90.0,100.0,110.0,120.0,130.0,140.0])
plt.xticks(ticks=["abr/19","maio/19","jun/19","jul/19","ago/19","set/19","out/19","nov/19","dez/19","jan/20","fev/20","mar/20","abr/20"
], labels = ["abr/19","maio/19","jun/19","jul/19","ago/19","set/19","out/19","nov/19","dez/19","jan/20","fev/20","mar/20","abr/20"])
plt.gcf().set_size_inches(20, 18)
plt.show()

#MÓVEIS E ELETRODOMÉSTICOS NO ESTADO DE SP 
import pandas as pd

data = pd.read_csv('sp-moveis.csv',sep=';',header = None)
data = pd.DataFrame(data)

import matplotlib.pyplot as plt
x = data[0]
y = data[1]
plt.plot(x, y,'r--')
plt.xlabel("Tempo")
plt.ylabel("Volume")
plt.title('Volume de vendas de Móveis e Eletrodomésticos no estado de São Paulo', fontsize = 24)
plt.yticks(ticks=[40.0,50.0,60.0,70.0,80.0,90.0,100.0,110.0,120.0,130.0,140.0], labels = [40.0,50.0,60.0,70.0,80.0,90.0,100.0,110.0,120.0,130.0,140.0])
plt.xticks(ticks=["abr/19","maio/19","jun/19","jul/19","ago/19","set/19","out/19","nov/19","dez/19","jan/20","fev/20","mar/20","abr/20"
], labels = ["abr/19","maio/19","jun/19","jul/19","ago/19","set/19","out/19","nov/19","dez/19","jan/20","fev/20","mar/20","abr/20"])
plt.gcf().set_size_inches(20, 18)
plt.show()

# %%
#VOLUME DE VENDAS DE MÓVEIS E ELETRODOMÉSTICOS POR ESTADO DO BRASIL 
import csv
import pandas as pd
import os

data = pd.read_csv('estados.csv',sep=';',header = None)
data = pd.DataFrame(data)

import matplotlib.pyplot as plt
x = data[0]
y1 = data[2]
y2 = data[3]
y3 = data[4]
y4 = data[5]
y5 = data[6]
y6 = data[7]
y7 = data[8]
y8 = data[9]
y9 = data[10]
y10 = data[11]
y11 = data[12]

plt.plot(x, y1, label = "Ceará")
plt.plot(x, y2,label = "Pernambuco")
plt.plot(x, y3,label = "Bahia")
plt.plot(x, y4,label = "Minas Gerais")
plt.plot(x, y5,label = "Espirito Santo")
plt.plot(x, y6,label = "Rio de Janeiro")
plt.plot(x, y7,label = "São Paulo")
plt.plot(x, y8,label = "Paraná")
plt.plot(x, y9,label = "Santa Catarina")
plt.plot(x, y10,label = "Rio Grande do Sul")
plt.plot(x, y11,label = "Goiás")

plt.xlabel("Tempo")
plt.ylabel("Volume")
plt.title('Volume de vendas de Móveis e Eletrodomésticos por estado durante a fase incial da pandemia', fontsize = 24)
plt.yticks(ticks=[40.0,50.0,60.0,70.0,80.0,90.0,100.0,110.0,120.0,130.0,140.0], labels = [40.0,50.0,60.0,70.0,80.0,90.0,100.0,110.0,120.0,130.0,140.0])
plt.xticks(ticks=["abr/19","maio/19","jun/19","jul/19","ago/19","set/19","out/19","nov/19","dez/19","jan/20","fev/20","mar/20","abr/20"
], labels = ["abr/19","maio/19","jun/19","jul/19","ago/19","set/19","out/19","nov/19","dez/19","jan/20","fev/20","mar/20","abr/20"])
plt.legend(fontsize = 15)
plt.gcf().set_size_inches(20, 18)
plt.show()
